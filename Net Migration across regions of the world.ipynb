# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#Using Pandas to read Our Data
df = pd.read_csv('countries of the world.csv', sep=',',decimal=',')
df
# Out:
#                    Country                               Region  Population  \
# 0             Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1                 Albania   EASTERN EUROPE                          3581655
# 2                 Algeria   NORTHERN AFRICA                        32930091
# 3          American Samoa   OCEANIA                                   57794
# 4                 Andorra   WESTERN EUROPE                            71201
# 5                  Angola   SUB-SAHARAN AFRICA                     12127071
# 6                Anguilla               LATIN AMER. & CARIB           13477
# 7       Antigua & Barbuda               LATIN AMER. & CARIB           69108
# 8               Argentina               LATIN AMER. & CARIB        39921833
# 9                 Armenia                  C.W. OF IND. STATES      2976372
# 10                  Aruba               LATIN AMER. & CARIB           71891
# ...

# %%
#drop some columns that aren't needed for our analysis
data = df.drop(['Area (sq. mi.)', 'Pop. Density (per sq. mi.)','Coastline (coast/area ratio)','Infant mortality (per 1000 births)',
               'Other (%)', 'Agriculture', 'Industry', 'Service', 'Arable (%)','Crops (%)','Climate' ], axis=1)
data
# Out:
#                    Country                               Region  Population  \
# 0             Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1                 Albania   EASTERN EUROPE                          3581655
# 2                 Algeria   NORTHERN AFRICA                        32930091
# 3          American Samoa   OCEANIA                                   57794
# 4                 Andorra   WESTERN EUROPE                            71201
# 5                  Angola   SUB-SAHARAN AFRICA                     12127071
# 6                Anguilla               LATIN AMER. & CARIB           13477
# 7       Antigua & Barbuda               LATIN AMER. & CARIB           69108
# 8               Argentina               LATIN AMER. & CARIB        39921833
# 9                 Armenia                  C.W. OF IND. STATES      2976372
# 10                  Aruba               LATIN AMER. & CARIB           71891
# ...

# %%
#Get an info about our new dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 9 columns):
# Country               227 non-null object
# Region                227 non-null object
# Population            227 non-null int64
# Net migration         224 non-null float64
# GDP ($ per capita)    226 non-null float64
# Literacy (%)          209 non-null float64
# Phones (per 1000)     223 non-null float64
# Birthrate             224 non-null float64
# Deathrate             223 non-null float64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 16.0+ KB

# %%
#To describe our dataset
data.describe()
# Out:
#          Population  Net migration  GDP ($ per capita)  Literacy (%)  \
# count  2.270000e+02     224.000000          226.000000    209.000000
# mean   2.874028e+07       0.038125         9689.823009     82.838278
# std    1.178913e+08       4.889269        10049.138513     19.722173
# min    7.026000e+03     -20.990000          500.000000     17.600000
# 25%    4.376240e+05      -0.927500         1900.000000     70.600000
# 50%    4.786994e+06       0.000000         5550.000000     92.500000
# 75%    1.749777e+07       0.997500        15700.000000     98.000000
# max    1.313974e+09      23.060000        55100.000000    100.000000
#
#        Phones (per 1000)   Birthrate   Deathrate
# count         223.000000  224.000000  223.000000
# mean          236.061435   22.114732    9.241345
# std           227.991829   11.176716    4.990026
# min             0.200000    7.290000    2.290000
# 25%            37.800000   12.672500    5.910000
# ...

# %%
#To view our dataset headings
data.head()
# Out:
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    Net migration  GDP ($ per capita)  Literacy (%)  Phones (per 1000)  \
# 0          23.06               700.0          36.0                3.2
# 1          -4.93              4500.0          86.5               71.2
# 2          -0.39              6000.0          70.0               78.1
# 3         -20.71              8000.0          97.0              259.5
# 4           6.60             19000.0         100.0              497.2
#
#    Birthrate  Deathrate
# 0      46.60      20.34
# 1      15.11       5.22
# 2      17.14       4.61
# 3      22.46       3.27
# ...

# %%
#To view the tail end of  our dataset
data.tail()
# Out:
#              Country                               Region  Population  \
# 222       West Bank   NEAR EAST                               2460492
# 223  Western Sahara   NORTHERN AFRICA                          273008
# 224           Yemen   NEAR EAST                              21456188
# 225          Zambia   SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe   SUB-SAHARAN AFRICA                     12236805
#
#      Net migration  GDP ($ per capita)  Literacy (%)  Phones (per 1000)  \
# 222           2.98               800.0           NaN              145.2
# 223            NaN                 NaN           NaN                NaN
# 224           0.00               800.0          50.2               37.2
# 225           0.00               800.0          80.6                8.2
# 226           0.00              1900.0          90.7               26.8
#
#      Birthrate  Deathrate
# 222      31.67       3.92
# 223        NaN        NaN
# 224      42.89       8.30
# ...

# %%
#To view our dataset index
data.index
data
# Out:
#                    Country                               Region  Population  \
# 0             Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1                 Albania   EASTERN EUROPE                          3581655
# 2                 Algeria   NORTHERN AFRICA                        32930091
# 3          American Samoa   OCEANIA                                   57794
# 4                 Andorra   WESTERN EUROPE                            71201
# 5                  Angola   SUB-SAHARAN AFRICA                     12127071
# 6                Anguilla               LATIN AMER. & CARIB           13477
# 7       Antigua & Barbuda               LATIN AMER. & CARIB           69108
# 8               Argentina               LATIN AMER. & CARIB        39921833
# 9                 Armenia                  C.W. OF IND. STATES      2976372
# 10                  Aruba               LATIN AMER. & CARIB           71891
# ...

# %%
# to fill some of dataset with zeros that are empty
data.fillna(0,inplace=True)
data
# Out:
#                    Country                               Region  Population  \
# 0             Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1                 Albania   EASTERN EUROPE                          3581655
# 2                 Algeria   NORTHERN AFRICA                        32930091
# 3          American Samoa   OCEANIA                                   57794
# 4                 Andorra   WESTERN EUROPE                            71201
# 5                  Angola   SUB-SAHARAN AFRICA                     12127071
# 6                Anguilla               LATIN AMER. & CARIB           13477
# 7       Antigua & Barbuda               LATIN AMER. & CARIB           69108
# 8               Argentina               LATIN AMER. & CARIB        39921833
# 9                 Armenia                  C.W. OF IND. STATES      2976372
# 10                  Aruba               LATIN AMER. & CARIB           71891
# ...

# %%
## to see all the columns we are working with
print(data.columns)
# Out:
# Index(['Country', 'Region', 'Population', 'Net migration',
#        'GDP ($ per capita)', 'Literacy (%)', 'Phones (per 1000)', 'Birthrate',
#        'Deathrate'],
#       dtype='object')

# %%
## to read specific columns
print(data[['Region','Country', 
                 'Population','Net migration','GDP ($ per capita)']])
# Out:
#                                   Region                Country  Population  \
# 0          ASIA (EX. NEAR EAST)                    Afghanistan     31056997
# 1    EASTERN EUROPE                                    Albania      3581655
# 2    NORTHERN AFRICA                                   Algeria     32930091
# 3    OCEANIA                                    American Samoa        57794
# 4    WESTERN EUROPE                                    Andorra        71201
# 5    SUB-SAHARAN AFRICA                                 Angola     12127071
# 6                LATIN AMER. & CARIB                  Anguilla        13477
# 7                LATIN AMER. & CARIB         Antigua & Barbuda        69108
# 8                LATIN AMER. & CARIB                 Argentina     39921833
# 9                   C.W. OF IND. STATES                Armenia      2976372
# 10               LATIN AMER. & CARIB                     Aruba        71891
# ...

# %%
  ##Read each row 
#print(data_drop.iloc[1:4])
for index, row in data.iterrows():
    print(index,row)
# Out:
# 0 Country                                Afghanistan
# Region                ASIA (EX. NEAR EAST)
# Population                                 31056997
# Net migration                                 23.06
# GDP ($ per capita)                              700
# Literacy (%)                                     36
# Phones (per 1000)                               3.2
# Birthrate                                      46.6
# Deathrate                                     20.34
# Name: 0, dtype: object
# 1 Country                                          Albania
# Region                EASTERN EUROPE
# Population                                        3581655
# Net migration                                       -4.93
# GDP ($ per capita)                                   4500
# Literacy (%)                                         86.5
# Phones (per 1000)                                    71.2
# Birthrate                                           15.11
# ...

# %%
# To sort our dataset by some major variables
data.sort_values(by=['Region', 'Country','Net migration','GDP ($ per capita)'])
# Out:
#              Country                               Region  Population  \
# 0       Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 16       Bangladesh         ASIA (EX. NEAR EAST)            147365352
# 23           Bhutan         ASIA (EX. NEAR EAST)              2279723
# 29           Brunei         ASIA (EX. NEAR EAST)               379444
# 32            Burma         ASIA (EX. NEAR EAST)             47382633
# 34         Cambodia         ASIA (EX. NEAR EAST)             13881427
# 42            China         ASIA (EX. NEAR EAST)           1313973713
# 58       East Timor         ASIA (EX. NEAR EAST)              1062777
# 91        Hong Kong         ASIA (EX. NEAR EAST)              6940432
# 94            India         ASIA (EX. NEAR EAST)           1095351995
# 95        Indonesia         ASIA (EX. NEAR EAST)            245452739
# 96             Iran         ASIA (EX. NEAR EAST)             68688433
# ...

# %%
#find the mean of our major variable
data['Net migration'].mean()
# Out:
# 0.038125

# %%
#find the minimum value of our major variable
data['Net migration'].min()
# Out:
# 'high'

# %%
#find the maximum value of our major variable
data['Net migration'].max()
# Out:
# 23.06

# %%
#find the std of our major variable
data['Net migration'].std()
# Out:
# 4.889269211168734

# %%
#find the most occuring value of our major variable
data['Net migration'].mode()
# Out:
# 0    0.0
# dtype: float64

# %%
#find the mean of our 2nd major variable
data['GDP ($ per capita)'].mean()
# Out:
# 9689.823008849558

# %%
#find the minimum value of our  2nd major variable
data['GDP ($ per capita)'].min()
# Out:
# 500.0

# %%
#find the maximum value of our 2nd major variable
data['GDP ($ per capita)'].max()
# Out:
# 55100.0

# %%
#find the std of our 2nd major variable
data['GDP ($ per capita)'].std()
# Out:
# 10049.138513197227

# %%
#find the most occuring value of our 2nd major variable
data['GDP ($ per capita)'].mode()
# Out:
# 0    800.0
# dtype: float64

# %%
#To find the average of our vaiable - population
avg_population = sum(data.Population)/len(data.Population)
print("avg_population: ",avg_population)
# Out:
# avg_population:  28740284.365638766

# %%
#Using our set average to determine how high  or low a country's population is
data['population'] = ['high' if i > avg_population else 'low' for i in data.Population ]
data.loc[:226,["Country","population"]]
# Out:
#                    Country population
# 0             Afghanistan        high
# 1                 Albania         low
# 2                 Algeria        high
# 3          American Samoa         low
# 4                 Andorra         low
# 5                  Angola         low
# 6                Anguilla         low
# 7       Antigua & Barbuda         low
# 8               Argentina        high
# 9                 Armenia         low
# 10                  Aruba         low
# 11              Australia         low
# 12                Austria         low
# 13             Azerbaijan         low
# 14           Bahamas, The         low
# 15                Bahrain         low
# 16             Bangladesh        high
# 17               Barbados         low
# 18                Belarus         low
# 19                Belgium         low
# 20                 Belize         low
# 21                  Benin         low
# 22                Bermuda         low
# 23                 Bhutan         low
# ...

# %%
#Using our set average to determine other major variable 
data['Net migration'] = ['high' if i > avg_population else 'low' for i in data.Population ]
data.loc[:,["Country","Net migration","GDP ($ per capita)"]]
# Out:
#                    Country Net migration  GDP ($ per capita)
# 0             Afghanistan           high               700.0
# 1                 Albania            low              4500.0
# 2                 Algeria           high              6000.0
# 3          American Samoa            low              8000.0
# 4                 Andorra            low             19000.0
# 5                  Angola            low              1900.0
# 6                Anguilla            low              8600.0
# 7       Antigua & Barbuda            low             11000.0
# 8               Argentina           high             11200.0
# 9                 Armenia            low              3500.0
# 10                  Aruba            low             28000.0
# 11              Australia            low             29000.0
# 12                Austria            low             30000.0
# 13             Azerbaijan            low              3400.0
# ...

# %%
#To get a list of regions we have
data['Region'].unique()
# Out:
# array(['ASIA (EX. NEAR EAST)         ',
#        'EASTERN EUROPE                     ',
#        'NORTHERN AFRICA                    ',
#        'OCEANIA                            ',
#        'WESTERN EUROPE                     ',
#        'SUB-SAHARAN AFRICA                 ', 'LATIN AMER. & CARIB    ',
#        'C.W. OF IND. STATES ', 'NEAR EAST                          ',
#        'NORTHERN AMERICA                   ',
#        'BALTICS                            '], dtype=object)

# %%
#To determine how many regions we have
len(data['Region'].unique())
# Out:
# 11

# %%
#data['Net migration']

# %%
#To check how many null values we have in our dataset
data.isnull().any().any()
# Out:
# False

# %% [markdown]
# # Bar Chat

# %%
# To find the number of countries by in each region
region = data["Region"].value_counts()
plt.figure(figsize=(10,7))
sns.barplot(x=region.index,y=region.values)
plt.xticks(rotation=90)
plt.ylabel('Number of countries')
plt.xlabel('Region')
plt.title('Number of Countries by REGİON',color = 'red',fontsize=20)
plt.plot()
# Out:
# []

# %%
# To find the GDP for each region
region = data["Region"].value_counts()
plt.figure(figsize=(10,7))
sns.barplot(x=region.index,y=region.values)
plt.xticks(rotation=90)
plt.ylabel('GDP ($ per capita)')
plt.xlabel('Region')
plt.title('GDP by REGİON',color = 'green',fontsize=20)
plt.plot()
# Out:
# []

# %%
# To find the net migration in each region
region = data["Region"].value_counts()
plt.figure(figsize=(10,7))
sns.barplot(x=region.index,y=region.values)
plt.xticks(rotation=90)
plt.ylabel('Net migration')
plt.xlabel('Region')
plt.title('Net migration by REGİON',color = 'blue',fontsize=20)
plt.plot()
# Out:
# []

# %%
# To find the population in each region
region = data["Region"].value_counts()
plt.figure(figsize=(10,7))
sns.barplot(x=region.index,y=region.values)
plt.xticks(rotation=90)
plt.ylabel('Population')
plt.xlabel('Region')
plt.title('Population by REGİON',color = 'blue',fontsize=20)
plt.plot()
# Out:
# []

# %% [markdown]
# # Box Plot

# %%
#Using a box plot to see gdp by region
group = data.groupby("Region")
group.mean()

sns.boxplot(x=data["Region"],y=data["GDP ($ per capita)"],data=data, width=0.7,palette="Set2",fliersize=5)
plt.xticks(rotation=90)
plt.title("GDP BY REGİON",color="green")

plt.plot()
# Out:
# []

# %%
#Using a box plot to see net migration by region
group = data.groupby("Region")
group.mean()

sns.boxplot(x=data["Region"],y=data["Net migration"],data=data, width=0.7,palette="Set2",fliersize=5)
plt.xticks(rotation=90)
plt.title("Net migration BY REGİON",color="red")

plt.plot()
# Out:
# []

# %%
#Using a box plot to see population by region
group = data.groupby("Region")
group.mean()

sns.boxplot(x=data["Region"],y=data["Population"],data=data, width=0.7,palette="Set2",fliersize=5)
plt.xticks(rotation=90)
plt.title("Population BY REGİON",color="red")

plt.plot()
# Out:
# []

# %% [markdown]
# #Violin Plot

# %%
#Using a violin plot to see other by variables
sns.set(style="whitegrid")
sns.violinplot(x="Literacy (%)",y="Phones (per 1000)",data=df,hue="Region",palette="PRGn")

plt.plot()
# Out:
# []

# %% [markdown]
# # Strip Plot

# %%
#Using a strip plot to see population by region
sns.stripplot(x="Region",y="Population",data=data,color="m")

plt.xticks(rotation=90)

plt.plot
# Out:
# <function matplotlib.pyplot.plot(*args, scalex=True, scaley=True, data=None, **kwargs)>

# %% [markdown]
# # Matplotlib

# %%
# scatter diagram for birthrate and deathrate
plt.scatter(data["Birthrate"],data["Deathrate"],marker='^',facecolor='green')

plt.grid(True)

plt.xlabel('Birthrate')
plt.ylabel('Deathrate')

plt.title("Scatter Plot")

plt.legend(loc='upper left')

plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
#Histogram showing the rate of net migration across regions
plt.hist(data["Net migration"], bins=10,density=True, facecolor='g', alpha=0.75)

plt.xlabel('Net migration')

plt.ylabel('Rate')

plt.title('Histogram Plot')

plt.grid(True)

plt.show()
# Out:
# C:\Users\VICTOR\Anaconda3\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\VICTOR\Anaconda3\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
#Piechat showing the net migrations across regions 
explode = (0, 0.1, 0, 0,0,0,0)

sizes=[15,10,25,5,30,5,10]

labels="ASIA","EASTERN EUROPE","NORTHERN AFRICA","OCEANIA","WESTERN EUROPE","SUB-SAHARAN AFRICA","NORTHERN AMERICA"

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels,explode=explode, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()
